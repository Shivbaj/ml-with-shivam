# %%
  import numpy as np

# %%
np.random.rand(3, 2)        # uniform [0,1)
np.random.randn(3, 2)       # normal distribution
np.random.randint(0, 10, (3, 3))
# Out:
# array([[6, 2, 1],
#        [0, 6, 6],
#        [5, 5, 2]])
